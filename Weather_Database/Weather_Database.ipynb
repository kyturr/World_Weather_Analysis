# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
## Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des=city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_des})

# If an error is experienced, skip the city.
    except:
        print(f"{city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | portmore
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | channel-port aux basques
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | christchurch
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | houma
# Processing Record 10 of Set 1 | shirokiy
# Processing Record 11 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | deputatskiy
# Processing Record 14 of Set 1 | taltal
# Processing Record 15 of Set 1 | winchester
# Processing Record 16 of Set 1 | oistins
# Processing Record 17 of Set 1 | saint-pierre
# Processing Record 18 of Set 1 | belyy yar
# Processing Record 19 of Set 1 | arkhangelsk
# Processing Record 20 of Set 1 | kibaya
# Processing Record 21 of Set 1 | poum
# Processing Record 22 of Set 1 | mount gambier
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | chukhloma
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | aragarcas
# Processing Record 29 of Set 1 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | provost
# Processing Record 32 of Set 1 | port hardy
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | pirogovo
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | chicama
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | temple
# Processing Record 46 of Set 1 | houlung
# houlung not found. Skipping...
# Processing Record 47 of Set 1 | inverell
# Processing Record 48 of Set 1 | imeni zhelyabova
# Processing Record 49 of Set 1 | cherepovets
# Processing Record 50 of Set 1 | assiniboia
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | amderma
# amderma not found. Skipping...
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | haverfordwest
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | iquique
# Processing Record 12 of Set 2 | kailua
# Processing Record 13 of Set 2 | nezhinka
# Processing Record 14 of Set 2 | isla vista
# Processing Record 15 of Set 2 | jahrom
# jahrom not found. Skipping...
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | sambava
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | kununurra
# Processing Record 21 of Set 2 | margate
# Processing Record 22 of Set 2 | aguie
# Processing Record 23 of Set 2 | warrnambool
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | srednekolymsk
# Processing Record 28 of Set 2 | upata
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | sekoma
# Processing Record 32 of Set 2 | dapdap
# Processing Record 33 of Set 2 | jojoima
# Processing Record 34 of Set 2 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | ahipara
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | caravelas
# Processing Record 39 of Set 2 | porto novo
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | kargasok
# Processing Record 42 of Set 2 | havre-saint-pierre
# Processing Record 43 of Set 2 | banda aceh
# Processing Record 44 of Set 2 | yanam
# Processing Record 45 of Set 2 | manjakandriana
# Processing Record 46 of Set 2 | san quintin
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | magadan
# Processing Record 49 of Set 2 | narsaq
# Processing Record 50 of Set 2 | marsh harbour
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | tanout
# Processing Record 3 of Set 3 | anadyr
# Processing Record 4 of Set 3 | kangaatsiaq
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | paysandu
# Processing Record 7 of Set 3 | mersing
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | livadiya
# Processing Record 10 of Set 3 | mbandaka
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | dicabisagan
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | paamiut
# Processing Record 16 of Set 3 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | freeport
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | meulaboh
# Processing Record 23 of Set 3 | jarjis
# jarjis not found. Skipping...
# Processing Record 24 of Set 3 | marsa matruh
# Processing Record 25 of Set 3 | litovko
# Processing Record 26 of Set 3 | ucluelet
# Processing Record 27 of Set 3 | bafoulabe
# Processing Record 28 of Set 3 | lauria
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | colac
# Processing Record 31 of Set 3 | goderich
# Processing Record 32 of Set 3 | belmonte
# Processing Record 33 of Set 3 | flin flon
# Processing Record 34 of Set 3 | metro
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | la ronge
# Processing Record 37 of Set 3 | aiken
# Processing Record 38 of Set 3 | basco
# Processing Record 39 of Set 3 | nortelandia
# Processing Record 40 of Set 3 | yar-sale
# Processing Record 41 of Set 3 | cherskiy
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | acajutla
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | daru
# Processing Record 47 of Set 3 | azul
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | campoverde
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | katsina
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | alofi
# Processing Record 7 of Set 4 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 8 of Set 4 | buon me thuot
# buon me thuot not found. Skipping...
# Processing Record 9 of Set 4 | komsomolskiy
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | broken hill
# Processing Record 12 of Set 4 | trinidad
# Processing Record 13 of Set 4 | yerbogachen
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | husavik
# Processing Record 16 of Set 4 | atar
# Processing Record 17 of Set 4 | qiqihar
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 21 of Set 4 | challans
# Processing Record 22 of Set 4 | walvis bay
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | tura
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | ayios kirikos
# ayios kirikos not found. Skipping...
# Processing Record 28 of Set 4 | flinders
# Processing Record 29 of Set 4 | plymouth
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | cerete
# Processing Record 32 of Set 4 | ijaki
# ijaki not found. Skipping...
# Processing Record 33 of Set 4 | sisimiut
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | jumla
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | te anau
# Processing Record 39 of Set 4 | karratha
# Processing Record 40 of Set 4 | bac lieu
# Processing Record 41 of Set 4 | uzhur
# Processing Record 42 of Set 4 | fairbanks
# Processing Record 43 of Set 4 | astana
# Processing Record 44 of Set 4 | jensen beach
# Processing Record 45 of Set 4 | talnakh
# Processing Record 46 of Set 4 | ocara
# Processing Record 47 of Set 4 | nashua
# Processing Record 48 of Set 4 | bambous virieux
# Processing Record 49 of Set 4 | ziyamet
# ziyamet not found. Skipping...
# Processing Record 50 of Set 4 | opelousas
# Processing Record 1 of Set 5 | broome
# Processing Record 2 of Set 5 | cabedelo
# Processing Record 3 of Set 5 | talcahuano
# Processing Record 4 of Set 5 | kapuskasing
# Processing Record 5 of Set 5 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 6 of Set 5 | gambela
# Processing Record 7 of Set 5 | aripuana
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | burica
# burica not found. Skipping...
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | kankon
# Processing Record 12 of Set 5 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 13 of Set 5 | belle fourche
# Processing Record 14 of Set 5 | saleaula
# saleaula not found. Skipping...
# Processing Record 15 of Set 5 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 16 of Set 5 | kamenka
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | hambantota
# Processing Record 19 of Set 5 | korla
# Processing Record 20 of Set 5 | butaritari
# Processing Record 21 of Set 5 | san cristobal
# Processing Record 22 of Set 5 | necochea
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | samalaeulu
# samalaeulu not found. Skipping...
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | banyo
# Processing Record 28 of Set 5 | tocache
# Processing Record 29 of Set 5 | vazhiny
# Processing Record 30 of Set 5 | egvekinot
# Processing Record 31 of Set 5 | urucara
# Processing Record 32 of Set 5 | darhan
# Processing Record 33 of Set 5 | siocon
# Processing Record 34 of Set 5 | hervey bay
# Processing Record 35 of Set 5 | moroni
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | dunedin
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | najran
# Processing Record 42 of Set 5 | chiredzi
# Processing Record 43 of Set 5 | basyanovskiy
# basyanovskiy not found. Skipping...
# Processing Record 44 of Set 5 | augusto correa
# Processing Record 45 of Set 5 | la macarena
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | bokspits
# bokspits not found. Skipping...
# Processing Record 48 of Set 5 | suntar
# Processing Record 49 of Set 5 | hoquiam
# Processing Record 50 of Set 5 | porto santo
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | cassilandia
# Processing Record 3 of Set 6 | bilma
# Processing Record 4 of Set 6 | nong bua
# Processing Record 5 of Set 6 | bondo
# Processing Record 6 of Set 6 | svetlyy
# Processing Record 7 of Set 6 | olga
# Processing Record 8 of Set 6 | port macquarie
# Processing Record 9 of Set 6 | kedrovyy
# Processing Record 10 of Set 6 | atlantic beach
# Processing Record 11 of Set 6 | hit
# Processing Record 12 of Set 6 | barrow
# Processing Record 13 of Set 6 | ulaanbaatar
# Processing Record 14 of Set 6 | solginskiy
# Processing Record 15 of Set 6 | palmer
# Processing Record 16 of Set 6 | nguiu
# nguiu not found. Skipping...
# Processing Record 17 of Set 6 | celestun
# Processing Record 18 of Set 6 | akdepe
# Processing Record 19 of Set 6 | dom pedrito
# Processing Record 20 of Set 6 | peniche
# Processing Record 21 of Set 6 | oltedal
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | gumushane
# gumushane not found. Skipping...
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | katangli
# Processing Record 26 of Set 6 | nanakuli
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | mehamn
# Processing Record 30 of Set 6 | lavrentiya
# Processing Record 31 of Set 6 | hailar
# Processing Record 32 of Set 6 | nyrob
# Processing Record 33 of Set 6 | kraskino
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | east london
# Processing Record 36 of Set 6 | alenquer
# Processing Record 37 of Set 6 | tabou
# Processing Record 38 of Set 6 | verkh-chebula
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | zahesi
# Processing Record 42 of Set 6 | port-gentil
# Processing Record 43 of Set 6 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 44 of Set 6 | goranboy
# Processing Record 45 of Set 6 | otradnoye
# Processing Record 46 of Set 6 | khani
# Processing Record 47 of Set 6 | mahibadhoo
# Processing Record 48 of Set 6 | nador
# Processing Record 49 of Set 6 | baykit
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | mount barker
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | mossendjo
# Processing Record 4 of Set 7 | catuday
# Processing Record 5 of Set 7 | tahoua
# Processing Record 6 of Set 7 | kabare
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | oranjestad
# Processing Record 9 of Set 7 | pangody
# Processing Record 10 of Set 7 | qinhuangdao
# Processing Record 11 of Set 7 | taiyuan
# Processing Record 12 of Set 7 | deer lake
# Processing Record 13 of Set 7 | lata
# Processing Record 14 of Set 7 | ensley
# Processing Record 15 of Set 7 | waingapu
# Processing Record 16 of Set 7 | omboue
# Processing Record 17 of Set 7 | santa cruz cabralia
# Processing Record 18 of Set 7 | sabha
# Processing Record 19 of Set 7 | tual
# Processing Record 20 of Set 7 | atocha
# Processing Record 21 of Set 7 | kapaa
# Processing Record 22 of Set 7 | awjilah
# Processing Record 23 of Set 7 | ruatoria
# ruatoria not found. Skipping...
# Processing Record 24 of Set 7 | tahta
# Processing Record 25 of Set 7 | rayong
# Processing Record 26 of Set 7 | lahaina
# Processing Record 27 of Set 7 | padang
# Processing Record 28 of Set 7 | las palmas
# Processing Record 29 of Set 7 | kibre mengist
# Processing Record 30 of Set 7 | touros
# Processing Record 31 of Set 7 | vagur
# Processing Record 32 of Set 7 | fort nelson
# Processing Record 33 of Set 7 | da lat
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | bulawayo
# Processing Record 36 of Set 7 | boke
# Processing Record 37 of Set 7 | tocuila
# Processing Record 38 of Set 7 | quepos
# Processing Record 39 of Set 7 | alamogordo
# Processing Record 40 of Set 7 | kamyshla
# Processing Record 41 of Set 7 | malanville
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | urdzhar
# urdzhar not found. Skipping...
# Processing Record 44 of Set 7 | spassk-dalniy
# Processing Record 45 of Set 7 | vallenar
# Processing Record 46 of Set 7 | anshun
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | buctzotz
# Processing Record 50 of Set 7 | voyvozh
# Processing Record 1 of Set 8 | abu samrah
# Processing Record 2 of Set 8 | wilmington island
# Processing Record 3 of Set 8 | vieques
# Processing Record 4 of Set 8 | pathein
# Processing Record 5 of Set 8 | fukue
# Processing Record 6 of Set 8 | saldanha
# Processing Record 7 of Set 8 | axim
# Processing Record 8 of Set 8 | lewiston
# Processing Record 9 of Set 8 | onega
# Processing Record 10 of Set 8 | liberal
# Processing Record 11 of Set 8 | wanning
# Processing Record 12 of Set 8 | talara
# Processing Record 13 of Set 8 | khovu-aksy
# Processing Record 14 of Set 8 | srandakan
# Processing Record 15 of Set 8 | tawang
# Processing Record 16 of Set 8 | khasan
# Processing Record 17 of Set 8 | constitucion
# Processing Record 18 of Set 8 | jiayuguan
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | khorinsk
# Processing Record 21 of Set 8 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 22 of Set 8 | zaysan
# Processing Record 23 of Set 8 | ambalavao
# Processing Record 24 of Set 8 | den helder
# Processing Record 25 of Set 8 | arman
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | gainesville
# Processing Record 28 of Set 8 | namwala
# Processing Record 29 of Set 8 | fortuna
# Processing Record 30 of Set 8 | fort saint james
# Processing Record 31 of Set 8 | alegrete
# Processing Record 32 of Set 8 | lima
# Processing Record 33 of Set 8 | finnsnes
# Processing Record 34 of Set 8 | nanortalik
# Processing Record 35 of Set 8 | sahuaripa
# Processing Record 36 of Set 8 | petrovsk-zabaykalskiy
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | nunoa
# Processing Record 39 of Set 8 | sakaiminato
# Processing Record 40 of Set 8 | williston
# Processing Record 41 of Set 8 | oranjemund
# Processing Record 42 of Set 8 | samusu
# samusu not found. Skipping...
# Processing Record 43 of Set 8 | rawannawi
# rawannawi not found. Skipping...
# Processing Record 44 of Set 8 | khorixas
# Processing Record 45 of Set 8 | calituban
# Processing Record 46 of Set 8 | jatiroto
# Processing Record 47 of Set 8 | pacific grove
# Processing Record 48 of Set 8 | calama
# Processing Record 49 of Set 8 | yulara
# Processing Record 50 of Set 8 | gazli
# Processing Record 1 of Set 9 | nelson bay
# Processing Record 2 of Set 9 | sao jose da coroa grande
# Processing Record 3 of Set 9 | seoul
# Processing Record 4 of Set 9 | geilo
# Processing Record 5 of Set 9 | umm kaddadah
# Processing Record 6 of Set 9 | nabire
# Processing Record 7 of Set 9 | coffeyville
# Processing Record 8 of Set 9 | yuanping
# Processing Record 9 of Set 9 | chimoio
# Processing Record 10 of Set 9 | aleksandrov gay
# Processing Record 11 of Set 9 | tezu
# Processing Record 12 of Set 9 | giddalur
# Processing Record 13 of Set 9 | aswan
# Processing Record 14 of Set 9 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 15 of Set 9 | totoral
# Processing Record 16 of Set 9 | noumea
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | beringovskiy
# Processing Record 19 of Set 9 | rongcheng
# Processing Record 20 of Set 9 | olinda
# Processing Record 21 of Set 9 | san lorenzo
# Processing Record 22 of Set 9 | mayumba
# Processing Record 23 of Set 9 | chingirlau
# Processing Record 24 of Set 9 | kefamenanu
# Processing Record 25 of Set 9 | vardo
# Processing Record 26 of Set 9 | kalmunai
# Processing Record 27 of Set 9 | magomeni
# Processing Record 28 of Set 9 | barbar
# barbar not found. Skipping...
# Processing Record 29 of Set 9 | lolua
# lolua not found. Skipping...
# Processing Record 30 of Set 9 | verkhoyansk
# Processing Record 31 of Set 9 | manggar
# Processing Record 32 of Set 9 | shache
# Processing Record 33 of Set 9 | leshukonskoye
# Processing Record 34 of Set 9 | gat
# Processing Record 35 of Set 9 | karabuk
# Processing Record 36 of Set 9 | ambilobe
# Processing Record 37 of Set 9 | norman wells
# Processing Record 38 of Set 9 | pangnirtung
# Processing Record 39 of Set 9 | xuanhua
# Processing Record 40 of Set 9 | acarau
# Processing Record 41 of Set 9 | taoudenni
# Processing Record 42 of Set 9 | hami
# Processing Record 43 of Set 9 | saint george
# Processing Record 44 of Set 9 | yeppoon
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | kuruman
# Processing Record 47 of Set 9 | lodwar
# Processing Record 48 of Set 9 | skegness
# Processing Record 49 of Set 9 | kieta
# Processing Record 50 of Set 9 | espanola
# Processing Record 1 of Set 10 | clyde river
# Processing Record 2 of Set 10 | praia
# Processing Record 3 of Set 10 | teya
# Processing Record 4 of Set 10 | maridi
# Processing Record 5 of Set 10 | garcia hernandez
# Processing Record 6 of Set 10 | tomari
# Processing Record 7 of Set 10 | namibe
# Processing Record 8 of Set 10 | faya
# Processing Record 9 of Set 10 | zatoka
# Processing Record 10 of Set 10 | ballina
# Processing Record 11 of Set 10 | maruko
# Processing Record 12 of Set 10 | mindif
# Processing Record 13 of Set 10 | tateyama
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | mitsamiouli
# Processing Record 16 of Set 10 | saint anthony
# Processing Record 17 of Set 10 | russell
# Processing Record 18 of Set 10 | mezobereny
# Processing Record 19 of Set 10 | meiktila
# Processing Record 20 of Set 10 | buariki
# buariki not found. Skipping...
# Processing Record 21 of Set 10 | manyana
# Processing Record 22 of Set 10 | evensk
# Processing Record 23 of Set 10 | ko samui
# Processing Record 24 of Set 10 | qena
# Processing Record 25 of Set 10 | utiroa
# utiroa not found. Skipping...
# Processing Record 26 of Set 10 | yakeshi
# Processing Record 27 of Set 10 | nalut
# Processing Record 28 of Set 10 | fayetteville
# Processing Record 29 of Set 10 | karistos
# karistos not found. Skipping...
# Processing Record 30 of Set 10 | lahij
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | metaxades
# Processing Record 33 of Set 10 | tambul
# tambul not found. Skipping...
# Processing Record 34 of Set 10 | krasnoarmeysk
# Processing Record 35 of Set 10 | maloshuyka
# maloshuyka not found. Skipping...
# Processing Record 36 of Set 10 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 37 of Set 10 | qui nhon
# Processing Record 38 of Set 10 | lexington
# Processing Record 39 of Set 10 | emirdag
# Processing Record 40 of Set 10 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 41 of Set 10 | olovyannaya
# Processing Record 42 of Set 10 | bulaevo
# Processing Record 43 of Set 10 | calamar
# Processing Record 44 of Set 10 | sioux lookout
# Processing Record 45 of Set 10 | miri
# Processing Record 46 of Set 10 | kushiro
# Processing Record 47 of Set 10 | dakar
# Processing Record 48 of Set 10 | burley
# Processing Record 49 of Set 10 | kampot
# Processing Record 50 of Set 10 | helena
# Processing Record 1 of Set 11 | bur gabo
# bur gabo not found. Skipping...
# Processing Record 2 of Set 11 | hargeysa
# Processing Record 3 of Set 11 | lucea
# Processing Record 4 of Set 11 | nichinan
# Processing Record 5 of Set 11 | verkhnevilyuysk
# Processing Record 6 of Set 11 | pedernales
# Processing Record 7 of Set 11 | navalgund
# Processing Record 8 of Set 11 | kropachevo
# Processing Record 9 of Set 11 | maniitsoq
# Processing Record 10 of Set 11 | karaul
# karaul not found. Skipping...
# Processing Record 11 of Set 11 | santo nino
# Processing Record 12 of Set 11 | san vicente
# Processing Record 13 of Set 11 | qasigiannguit
# Processing Record 14 of Set 11 | bal-os
# Processing Record 15 of Set 11 | santa maria
# Processing Record 16 of Set 11 | khoni
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | ahuimanu
# Processing Record 19 of Set 11 | bo phloi
# Processing Record 20 of Set 11 | buraydah
# Processing Record 21 of Set 11 | barcelona
# Processing Record 22 of Set 11 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 23 of Set 11 | byron bay
# Processing Record 24 of Set 11 | longyearbyen
# Processing Record 25 of Set 11 | bowen
# Processing Record 26 of Set 11 | guarapari
# Processing Record 27 of Set 11 | cheyenne
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | wewak
# Processing Record 30 of Set 11 | kirs
# Processing Record 31 of Set 11 | ketchikan
# Processing Record 32 of Set 11 | neiafu
# Processing Record 33 of Set 11 | ust-nera
# Processing Record 34 of Set 11 | yershov
# Processing Record 35 of Set 11 | puerto carreno
# Processing Record 36 of Set 11 | sape
# Processing Record 37 of Set 11 | bonavista
# Processing Record 38 of Set 11 | itaituba
# Processing Record 39 of Set 11 | grand centre
# grand centre not found. Skipping...
# Processing Record 40 of Set 11 | isiro
# Processing Record 41 of Set 11 | dinghai
# Processing Record 42 of Set 11 | zhigansk
# Processing Record 43 of Set 11 | yirol
# yirol not found. Skipping...
# Processing Record 44 of Set 11 | naryan-mar
# Processing Record 45 of Set 11 | ajdabiya
# Processing Record 46 of Set 11 | tambopata
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | alice springs
# Processing Record 50 of Set 11 | kysyl-syr
# Processing Record 1 of Set 12 | konstantinovka
# Processing Record 2 of Set 12 | navrongo
# Processing Record 3 of Set 12 | vilhena
# Processing Record 4 of Set 12 | tukrah
# Processing Record 5 of Set 12 | hanstholm
# Processing Record 6 of Set 12 | toliary
# toliary not found. Skipping...
# Processing Record 7 of Set 12 | okha
# Processing Record 8 of Set 12 | omsukchan
# Processing Record 9 of Set 12 | luau
# Processing Record 10 of Set 12 | burnie
# Processing Record 11 of Set 12 | myitkyina
# Processing Record 12 of Set 12 | olafsvik
# Processing Record 13 of Set 12 | kuryk
# Processing Record 14 of Set 12 | tautira
# Processing Record 15 of Set 12 | mengen
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | yashalta
# Processing Record 18 of Set 12 | isoka
# Processing Record 19 of Set 12 | boende
# Processing Record 20 of Set 12 | warqla
# warqla not found. Skipping...
# Processing Record 21 of Set 12 | awbari
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | kizema
# Processing Record 24 of Set 12 | berlevag
# Processing Record 25 of Set 12 | hamilton
# Processing Record 26 of Set 12 | isangel
# Processing Record 27 of Set 12 | kindu
# Processing Record 28 of Set 12 | malino
# Processing Record 29 of Set 12 | mbanza-ngungu
# Processing Record 30 of Set 12 | tonantins
# Processing Record 31 of Set 12 | hecun
# Processing Record 32 of Set 12 | mount isa
# Processing Record 33 of Set 12 | batagay-alyta
# Processing Record 34 of Set 12 | alcaniz
# Processing Record 35 of Set 12 | san angelo
# Processing Record 36 of Set 12 | cheuskiny
# cheuskiny not found. Skipping...
# Processing Record 37 of Set 12 | gagnoa
# Processing Record 38 of Set 12 | yagodnoye
# Processing Record 39 of Set 12 | bontang
# Processing Record 40 of Set 12 | kavaratti
# Processing Record 41 of Set 12 | warmbad
# Processing Record 42 of Set 12 | hudson bay
# Processing Record 43 of Set 12 | nome
# Processing Record 44 of Set 12 | yumen
# Processing Record 45 of Set 12 | sumbawa
# sumbawa not found. Skipping...
# Processing Record 46 of Set 12 | tazovskiy
# Processing Record 47 of Set 12 | putina
# Processing Record 48 of Set 12 | esso
# Processing Record 49 of Set 12 | veraval
# Processing Record 50 of Set 12 | vao
# Processing Record 1 of Set 13 | sfantu gheorghe
# Processing Record 2 of Set 13 | bikaner
# Processing Record 3 of Set 13 | coihaique
# Processing Record 4 of Set 13 | kiruna
# Processing Record 5 of Set 13 | boundiali
# Processing Record 6 of Set 13 | gizo
# Processing Record 7 of Set 13 | belaya gora
# Processing Record 8 of Set 13 | la rioja
# Processing Record 9 of Set 13 | paraiso
# Processing Record 10 of Set 13 | gangapur
# Processing Record 11 of Set 13 | ayan
# Processing Record 12 of Set 13 | sulzbach-rosenberg
# Processing Record 13 of Set 13 | owando
# Processing Record 14 of Set 13 | imbituba
# Processing Record 15 of Set 13 | watertown
# Processing Record 16 of Set 13 | sudbury
# Processing Record 17 of Set 13 | sukhoverkovo
# sukhoverkovo not found. Skipping...
# Processing Record 18 of Set 13 | san rafael
# Processing Record 19 of Set 13 | klaksvik
# Processing Record 20 of Set 13 | skalistyy
# skalistyy not found. Skipping...
# Processing Record 21 of Set 13 | nakhon nayok
# Processing Record 22 of Set 13 | sorland
# Processing Record 23 of Set 13 | jacareacanga
# Processing Record 24 of Set 13 | plettenberg bay
# Processing Record 25 of Set 13 | prado
# Processing Record 26 of Set 13 | nouadhibou
# Processing Record 27 of Set 13 | mercedes
# Processing Record 28 of Set 13 | zakamensk
# Processing Record 29 of Set 13 | lianran
# Processing Record 30 of Set 13 | huangchuan
# Processing Record 31 of Set 13 | boueni
# Processing Record 32 of Set 13 | lumut
# Processing Record 33 of Set 13 | chara
# Processing Record 34 of Set 13 | winslow
# Processing Record 35 of Set 13 | half moon bay
# Processing Record 36 of Set 13 | doha
# Processing Record 37 of Set 13 | ust-maya
# Processing Record 38 of Set 13 | voznesenskaya
# Processing Record 39 of Set 13 | kasongo-lunda
# Processing Record 40 of Set 13 | mitu
# Processing Record 41 of Set 13 | barawe
# barawe not found. Skipping...
# Processing Record 42 of Set 13 | borogontsy
# Processing Record 43 of Set 13 | godda
# Processing Record 44 of Set 13 | roald
# Processing Record 45 of Set 13 | harbour breton
# Processing Record 46 of Set 13 | neman
# Processing Record 47 of Set 13 | tabora
# Processing Record 48 of Set 13 | ciudad bolivar
# Processing Record 49 of Set 13 | piacabucu
# Processing Record 50 of Set 13 | colares
# Processing Record 1 of Set 14 | mililani town
# Processing Record 2 of Set 14 | eldorado
# Processing Record 3 of Set 14 | celendin
# Processing Record 4 of Set 14 | mareeba
# Processing Record 5 of Set 14 | omaruru
# Processing Record 6 of Set 14 | senanga
# Processing Record 7 of Set 14 | nyurba
# Processing Record 8 of Set 14 | bereda
# Processing Record 9 of Set 14 | rungata
# rungata not found. Skipping...
# Processing Record 10 of Set 14 | toma
# Processing Record 11 of Set 14 | ridgecrest
# Processing Record 12 of Set 14 | mindelo
# Processing Record 13 of Set 14 | malwan
# malwan not found. Skipping...
# Processing Record 14 of Set 14 | ouro preto do oeste
# Processing Record 15 of Set 14 | aquiraz
# Processing Record 16 of Set 14 | bukama
# Processing Record 17 of Set 14 | dwarka
# Processing Record 18 of Set 14 | gamba
# Processing Record 19 of Set 14 | mozarlandia
# Processing Record 20 of Set 14 | ozu
# Processing Record 21 of Set 14 | santa rosa
# Processing Record 22 of Set 14 | manokwari
# Processing Record 23 of Set 14 | desa
# Processing Record 24 of Set 14 | alyangula
# Processing Record 25 of Set 14 | sivas
# Processing Record 26 of Set 14 | de aar
# Processing Record 27 of Set 14 | grindavik
# Processing Record 28 of Set 14 | kalabo
# Processing Record 29 of Set 14 | swan hill
# Processing Record 30 of Set 14 | kutum
# Processing Record 31 of Set 14 | arrifes
# Processing Record 32 of Set 14 | tidore
# tidore not found. Skipping...
# Processing Record 33 of Set 14 | la palma
# Processing Record 34 of Set 14 | ponta delgada
# Processing Record 35 of Set 14 | general roca
# Processing Record 36 of Set 14 | dolbeau
# dolbeau not found. Skipping...
# Processing Record 37 of Set 14 | kyzyl-suu
# Processing Record 38 of Set 14 | salalah
# Processing Record 39 of Set 14 | sakakah
# Processing Record 40 of Set 14 | mrirt
# mrirt not found. Skipping...
# Processing Record 41 of Set 14 | san carlos
# Processing Record 42 of Set 14 | shaoyang
# Processing Record 43 of Set 14 | manzanillo
# Processing Record 44 of Set 14 | bahia de caraquez
# Processing Record 45 of Set 14 | adrar
# Processing Record 46 of Set 14 | skagastrond
# skagastrond not found. Skipping...
# Processing Record 47 of Set 14 | muisne
# Processing Record 48 of Set 14 | tower
# Processing Record 49 of Set 14 | yarmouth
# Processing Record 50 of Set 14 | novyy urgal
# Processing Record 1 of Set 15 | susanville
# Processing Record 2 of Set 15 | lubana
# Processing Record 3 of Set 15 | sumenep
# Processing Record 4 of Set 15 | valdivia
# Processing Record 5 of Set 15 | mondovi
# Processing Record 6 of Set 15 | visby
# Processing Record 7 of Set 15 | huarmey
# Processing Record 8 of Set 15 | tapaua
# tapaua not found. Skipping...
# Processing Record 9 of Set 15 | pontes e lacerda
# Processing Record 10 of Set 15 | mandurah
# Processing Record 11 of Set 15 | dzaoudzi
# Processing Record 12 of Set 15 | ambon
# Processing Record 13 of Set 15 | iquitos
# Processing Record 14 of Set 15 | athabasca
# Processing Record 15 of Set 15 | madhubani
# Processing Record 16 of Set 15 | pringsewu
# Processing Record 17 of Set 15 | dragoman
# Processing Record 18 of Set 15 | santa isabel do rio negro
# Processing Record 19 of Set 15 | pipirig
# Processing Record 20 of Set 15 | maraba
# Processing Record 21 of Set 15 | udachnyy
# Processing Record 22 of Set 15 | marcona
# marcona not found. Skipping...
# Processing Record 23 of Set 15 | esna
# Processing Record 24 of Set 15 | hovd
# Processing Record 25 of Set 15 | the valley
# Processing Record 26 of Set 15 | sapa
# Processing Record 27 of Set 15 | zdvinsk
# Processing Record 28 of Set 15 | porto murtinho
# Processing Record 29 of Set 15 | chamba
# Processing Record 30 of Set 15 | koyilandi
# koyilandi not found. Skipping...
# Processing Record 31 of Set 15 | moron
# Processing Record 32 of Set 15 | losevo
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | floro
# Processing Record 35 of Set 15 | puerto madero
# Processing Record 36 of Set 15 | fare
# Processing Record 37 of Set 15 | batagay
# Processing Record 38 of Set 15 | kyakhta
# Processing Record 39 of Set 15 | volksrust
# Processing Record 40 of Set 15 | sinegorye
# Processing Record 41 of Set 15 | sibolga
# Processing Record 42 of Set 15 | mogadishu
# Processing Record 43 of Set 15 | sikeston
# Processing Record 44 of Set 15 | taksimo
# Processing Record 45 of Set 15 | galveston
# Processing Record 46 of Set 15 | wadi
# Processing Record 47 of Set 15 | chivay
# Processing Record 48 of Set 15 | labrea
# Processing Record 49 of Set 15 | nayoro
# Processing Record 50 of Set 15 | fukagawa
# Processing Record 1 of Set 16 | chkalovsk
# Processing Record 2 of Set 16 | amurzet
# Processing Record 3 of Set 16 | sinnamary
# Processing Record 4 of Set 16 | spetsai
# spetsai not found. Skipping...
# Processing Record 5 of Set 16 | wuhan
# Processing Record 6 of Set 16 | ambulu
# Processing Record 7 of Set 16 | praia da vitoria
# Processing Record 8 of Set 16 | pasighat
# Processing Record 9 of Set 16 | pitimbu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                  Portmore  17.9702  -76.8672     84.16        78
# 1                  Hermanus -34.4187   19.2345     50.43        81
# 2                     Vaini -21.2000 -175.2000     73.56        83
# 3  Channel-Port Aux Basques  47.5702  -59.1367     56.37        76
# 4                  Bengkulu  -3.8004  102.2655     84.40        68
# 5              Christchurch -43.5333  172.6333     51.91        66
# 6             Mar Del Plata -38.0023  -57.5575     40.08       100
# 7                   Rikitea -23.1203 -134.9692     75.29        71
# 8                     Houma  29.5958  -90.7195     80.60        91
# 9                  Shirokiy  49.7580  129.5230     83.14        68
#
#    Cloudiness  Wind Speed Country Current Description
# 0          20       14.97      JM          few clouds
# 1           0        6.49      ZA           clear sky
# 2          75       12.66      TO       broken clouds
# 3           2       13.15      CA           clear sky
# 4          84        7.07      ID          light rain
# 5          70        1.14      NZ       broken clouds
# 6           0        3.44      AR           clear sky
# 7           4        9.64      PF           clear sky
# 8           0        0.00      US           clear sky
# 9          68        7.16      RU       broken clouds

# %%
new_col=['City','Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df=city_data_df[new_col]
city_data_df.head()
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Portmore      JM  17.9702  -76.8672     84.16        78
# 1                  Hermanus      ZA -34.4187   19.2345     50.43        81
# 2                     Vaini      TO -21.2000 -175.2000     73.56        83
# 3  Channel-Port Aux Basques      CA  47.5702  -59.1367     56.37        76
# 4                  Bengkulu      ID  -3.8004  102.2655     84.40        68
#
#    Cloudiness  Wind Speed Current Description
# 0          20       14.97          few clouds
# 1           0        6.49           clear sky
# 2          75       12.66       broken clouds
# 3           2       13.15           clear sky
# 4          84        7.07          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
